# %% [markdown]
# # Moving Violations, Washington DC
# ## March 2022
# Dataset sourced from DC Open Data

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset_path = "./Datasets/Moving_Violations_Issued_in_March_2022.csv"

# %%
moving_violations_dataset = pd.read_csv(dataset_path, low_memory = False)

# %%
moving_violations_dataset.head()
# Out:
#    OBJECTID                            LOCATION      XCOORD     YCOORD  \
# 0  34438503                   1613 EUCLID ST NW  396780.390  139484.34
# 1  34438504                      502 23RD ST NW  395612.510  136519.40
# 2  34438511  INTER 3RD ST & INDEPENDENCE AVE SW  398683.171  135525.17
# 3  34597548                 I 395 SOUTHBOUND SW         NaN        NaN
# 4  34597549                2330 GOOD HOPE RD SE  402270.450  133068.76
#
#                ISSUE_DATE  ISSUE_TIME  ISSUING_AGENCY_CODE  \
# 0  2022/03/23 04:00:00+00        2357                   52
# 1  2022/03/31 04:00:00+00         325                   52
# 2  2022/03/28 04:00:00+00        1457                   23
# 3  2022/03/25 04:00:00+00        2221                    1
# 4  2022/03/05 05:00:00+00        1729                    6
#
#                    ISSUING_AGENCY_NAME ISSUING_AGENCY_SHORT VIOLATION_CODE  \
# 0  US. SECRET SERVICE UNIFORM DIVISION                 USSS           T672
# ...

# %% [markdown]
# #### Plot (XCOORD, YCOORD)
# To make life easier I'll convert every value to an integer.

# %%
def as_int(coord):
    return int(coord*1000)

x = moving_violations_dataset["XCOORD"].dropna().map(as_int)
y = moving_violations_dataset["YCOORD"].dropna().map(as_int)

FIG_WIDTH = 12
FIG_HEIGHT = 12

def draw(func, *args, **kwargs):
    plt.figure(figsize=(FIG_WIDTH, FIG_HEIGHT))
    func(*args, **kwargs)

# %% [markdown]
# #### Location Scatter Plot

# %%
draw(plt.scatter, x, y)

# %% [markdown]
# #### Location Histogram

# %%
draw(plt.hexbin, x, y, gridsize=50, bins='log')

# %% [markdown]
# #### Time Histogram

# %%
issue_time = moving_violations_dataset["ISSUE_TIME"].dropna()

# %%
draw(plt.hist, issue_time, bins=96)

# %% [markdown]
# #### State Plate

# %%
states = moving_violations_dataset["PLATE_STATE"]
for state in states.unique():
    if state.strip():
        total = len(moving_violations_dataset[states == state])
        print("Totals for {0}: {1}".format(state, total))
# Out:
# Totals for MD: 1194
# Totals for OH: 3
# Totals for VA: 836
# Totals for ME: 3
# Totals for DC: 901
# Totals for NY: 12
# Totals for TN: 3
# Totals for IL: 4
# Totals for MA: 6
# Totals for TX: 35
# Totals for GA: 13
# Totals for CA: 12
# Totals for NJ: 16
# Totals for AR: 1
# Totals for MI: 2
# Totals for KY: 2
# Totals for OK: 5
# Totals for WA: 2
# Totals for NC: 19
# Totals for IN: 4
# Totals for FL: 26
# Totals for ON: 1
# Totals for DE: 19
# Totals for LA: 2
# Totals for NH: 3
# Totals for PA: 25
# Totals for NV: 1
# Totals for SC: 7
# Totals for AZ: 3
# Totals for US: 5
# Totals for WV: 13
# Totals for NO: 2
# Totals for UN: 2
# Totals for XX: 1
# Totals for MS: 3
# Totals for YY: 2
# Totals for WI: 3
# Totals for MN: 2
# Totals for AL: 1
# Totals for MO: 9
# Totals for MT: 1
# Totals for CO: 1
# Totals for CT: 1
